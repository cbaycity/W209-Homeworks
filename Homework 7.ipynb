# %%
import altair as alt
import pandas as pd
import numpy as np
import json

# %%
data = pd.read_json('C:/Users/bayardcarlson/Dropbox/Berkeley MIDS/W209 Data Visualization and Communication/Homework 6/tweets.json')
data.head()
# Out:
#    retweeted                                             source  \
# 0      False  <a href="https://mobile.twitter.com" rel="nofo...
# 1      False  <a href="https://mobile.twitter.com" rel="nofo...
# 2      False  <a href="http://twitter.com/download/android" ...
# 3      False  <a href="http://twitter.com/download/android" ...
# 4      False  <a href="http://twitter.com/download/android" ...
#
#                                             entities display_text_range  \
# 0  {'user_mentions': [{'name': 'D3.js', 'screen_n...           [0, 293]
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...           [0, 131]
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...           [0, 182]
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...           [0, 152]
# 4  {'hashtags': [{'text': 'dataviz', 'indices': [...           [0, 122]
#
#    favorite_count               id_str  truncated  retweet_count  \
# 0              12  1302979067080302592      False              0
# ...

# %%
list_dates = list(data['created_at'])
week_days = [date.dayofweek for date in list_dates]

data['week_day'] = week_days

# %%
# Need to get tweet counts by week_day and hour.
group_by = data.groupby(['week_day','hour']).count()
group_by
# Out:
#                retweeted  source  entities  display_text_range  \
# week_day hour
# 0        0             6       6         6                   6
#          1             1       1         1                   1
#          2            13      13        13                  13
#          3             8       8         8                   8
#          4            38      38        38                  38
# ...                  ...     ...       ...                 ...
# 6        18           10      10        10                  10
#          19           10      10        10                  10
#          20            8       8         8                   8
#          21            9       9         9                   9
#          23            7       7         7                   7
#
#                favorite_count  id_str  truncated  retweet_count  id  \
# week_day hour
# 0        0                  6       6          6              6   6
# ...

# %%
x = np.array(group_by.index.to_frame().loc[:,'week_day'])
y = np.array(group_by.index.to_frame().loc[:,'hour'])
color = group_by['source']

final_dataset = pd.DataFrame(np.stack((x, y, color), axis = 1))
final_dataset.head()
# Out:
#    0  1   2
# 0  0  0   6
# 1  0  1   1
# 2  0  2  13
# 3  0  3   8
# 4  0  4  38

# %%
alt.Chart(final_dataset).mark_rect().encode(
    x= alt.X('0:N', axis=alt.Axis( title='Week Day')),
    y= alt.Y('1:N', axis=alt.Axis( title='Hour of Day')),
    color = alt.Color('2:Q', scale=alt.Scale(scheme='greenblue'), axis = alt.Axis(title = 'Tweet Count'))
).properties(title = 'Tweets by Weekday and Hour')
# Out:
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#    2018             copy.data = core.InlineData(values=[{}])
#    2019             return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2020         return super().to_dict(*args, **kwargs)
#    2021
#    2022     def add_selection(self, *selections):
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     391         if dct is None:
#     392             kwargs["validate"] = "deep"
# --> 393             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     394
#     395         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
# ...
